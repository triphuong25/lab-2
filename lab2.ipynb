# %%
# !unzip /content/lab2_aiot_public_dataset_deploy2.zip
# Out:
# Archive:  /content/lab2_aiot_public_dataset_deploy2.zip
#    creating: lab2_aiot_public_dataset_deploy 2/
#   inflating: __MACOSX/._lab2_aiot_public_dataset_deploy 2
#   inflating: lab2_aiot_public_dataset_deploy 2/.DS_Store
#   inflating: __MACOSX/lab2_aiot_public_dataset_deploy 2/._.DS_Store
#   inflating: lab2_aiot_public_dataset_deploy 2/requirements.txt
#   inflating: __MACOSX/lab2_aiot_public_dataset_deploy 2/._requirements.txt
#    creating: lab2_aiot_public_dataset_deploy 2/models/
#   inflating: __MACOSX/lab2_aiot_public_dataset_deploy 2/._models
#    creating: lab2_aiot_public_dataset_deploy 2/docs/
#   inflating: __MACOSX/lab2_aiot_public_dataset_deploy 2/._docs
#   inflating: lab2_aiot_public_dataset_deploy 2/README.md
#   inflating: __MACOSX/lab2_aiot_public_dataset_deploy 2/._README.md
#    creating: lab2_aiot_public_dataset_deploy 2/data/
#   inflating: __MACOSX/lab2_aiot_public_dataset_deploy 2/._data
#    creating: lab2_aiot_public_dataset_deploy 2/outputs/
# ...

# %%
# Đổi tên thư mục dưới đây cho khớp với tên thư mục sau khi giải nén
# %cd lab2_aiot_public_dataset_deploy

# Cài đặt các thư viện cần thiết theo yêu cầu của lab
# !pip install -r requirements.txt
# Out:
# /content/lab2_aiot_public_dataset_deploy
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 50.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 56.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 60.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: notebook
#     Found existing installation: notebook 6.5.7
#     Uninstalling notebook-6.5.7:
#       Successfully uninstalled notebook-6.5.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-kernel-gateway 2.5.2 requires notebook<7.0,>=5.7.6, but you have notebook 7.5.6 which is incompatible.
# ...

# %%
# %run notebooks/01_data_prep_baseline_deploy_ready.ipynb
# Out:
# PROJECT_ROOT = /content/lab2_aiot_public_dataset_deploy
# Dataset source: UCI Occupancy Detection public dataset via LuisM78 GitHub mirror
# - Downloaded: datatraining.txt -> /content/lab2_aiot_public_dataset_deploy/data/public_occupancy_detection/datatraining.txt
# - Downloaded: datatest.txt -> /content/lab2_aiot_public_dataset_deploy/data/public_occupancy_detection/datatest.txt
# - Downloaded: datatest2.txt -> /content/lab2_aiot_public_dataset_deploy/data/public_occupancy_detection/datatest2.txt
#
# Shape: (20560, 8)
#                   date  Temperature  Humidity  Light     CO2  HumidityRatio  \
# 0  2015-02-04 17:51:00        23.18   27.2720  426.0  721.25       0.004793
# 1  2015-02-04 17:51:59        23.15   27.2675  429.5  714.00       0.004783
# 2  2015-02-04 17:53:00        23.15   27.2450  426.0  713.50       0.004779
# 3  2015-02-04 17:54:00        23.15   27.2000  426.0  708.25       0.004772
# 4  2015-02-04 17:55:00        23.10   27.2000  426.0  704.50       0.004757
#
# ...

# %%
# Khởi chạy FastAPI ngầm ở cổng 8000
# !nohup uvicorn src.app:app --host 127.0.0.1 --port 8000 &
# Out:
# nohup: appending output to 'nohup.out'

# %%
# Gửi payload mẫu vào API /predict để test
# !python src/test_api.py
# Out:
# Checking /health ...
# 200 {'status': 'ok', 'model_loaded': True, 'model_version': 'lab2-v1'}
#
# Checking /model-info ...
# 200
# {
#   "model_name": "occupancy_logistic_regression_baseline",
#   "model_version": "lab2-v1",
#   "feature_cols": [
#     "Temperature",
#     "Humidity",
#     "Light",
#     "CO2",
#     "HumidityRatio",
#     "hour",
#     "dayofweek"
#   ],
#   "metrics": {
#     "accuracy": 0.9943579766536965,
#     "precision": 0.9750889679715302,
#     "recall": 0.9990884229717412,
#     "f1": 0.9869428185502026,
#     "roc_auc": 0.9988282300727526,
#     "confusion_matrix": [
#       [
#         4015,
#         28
#       ],
#       [
#         1,
#         1096
#       ]
#     ]
#   },
#   "decision_outputs": [
#     "CHECK_SENSOR_OR_DATA",
#     "ALERT_VENTILATION_AND_TURN_FAN_ON",
#     "ROOM_OCCUPIED_LIGHTING_NEEDED",
#     "ROOM_OCCUPIED_KEEP_COMFORT_MODE",
#     "ROOM_EMPTY_SAVE_ENERGY"
#   ]
# }
#
# Checking /predict ...
# 200
# {
#   "input": {
# ...

# %%
# Cài đặt localtunnel
# !npm install -g localtunnel

# Cấp phát đường dẫn công khai cho port 8000
# !npx localtunnel --port 8000
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧
# added 22 packages in 2s
# ⠧
# ⠧3 packages are looking for funding
# ⠧  run `npm fund` for details
# ⠧⠙⠹⠸⠼⠴your url is: https://few-eagles-juggle.loca.lt
